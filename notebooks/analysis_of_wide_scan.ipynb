# %% [markdown]
# # Analyze and plot first scan
# ## Settings:
# - hardware gain = 10
# - pluto antenna
# - emitter is not on

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "emitter_active_fastattack_scan.npz"
data = np.load(filename)
print(data.files)
# Out:
# ['arr_0', 'arr_1']

# %%
center_frequencies = data['arr_0']
max_gains = data['arr_1']

plt.figure
plt.plot(center_frequencies, max_gains)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain (dB)')
plt.title('Gain vs Frequency - Ayaslı Emitter Active (around 3.7Ghz) Fast Attack Scan')
plt.grid(True)
plt.savefig('emitter_active_FastAttack_scan_ayasli.png')
plt.show()
